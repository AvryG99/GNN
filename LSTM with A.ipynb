# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Attention
from keras import optimizers 
from sklearn.metrics import mean_squared_error

seed = 2345
np.random.seed(seed)
plt.style.use('ggplot')

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
data_raw = pd.read_csv("VNM.csv", index_col="Date", parse_dates=["Date"])
data_raw = data_raw.dropna()

# %%
dataset = pd.DataFrame(data_raw['Close'])
print(' Count row of data: ',len(dataset))

fig = plt.figure(figsize=(14, 6))
plt.plot(dataset)
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.title('Stock Price')
plt.show()
# Out:
#  Count row of data:  988

# %% [markdown]
# NORMALIZATION

# %%
dataset_norm = dataset.copy()
dataset[['Close']]
scaler = MinMaxScaler()
dataset_norm['Close'] = scaler.fit_transform(dataset[['Close']])
dataset_norm
# Out:
#                Close
# Date
# 2018-12-31  0.426881
# 2019-01-02  0.439560
# 2019-01-03  0.404057
# 2019-01-04  0.440406
# 2019-01-07  0.451395
# ...              ...
# 2022-11-23  0.120034
# 2022-11-25  0.158073
# 2022-11-28  0.177515
# 2022-11-29  0.211327
# 2022-11-30  0.260355
#
# [988 rows x 1 columns]

# %%
totaldata = dataset.values
totaldatatrain = int(len(totaldata)*0.75)
totaldataval = int(len(totaldata)*0.1)
totaldatatest = int(len(totaldata)*0.15)

# Store data into each partition
training_set = dataset_norm[0:totaldatatrain]
val_set=dataset_norm[totaldatatrain:totaldatatrain+totaldataval]
test_set = dataset_norm[totaldatatrain+totaldataval:]

# %%
# Initiaton value of lag
lag = 2
# sliding windows function
def create_sliding_windows(data,len_data,lag):
    x=[]
    y=[]
    for i in range(lag,len_data):
        x.append(data[i-lag:i,0])
        y.append(data[i,0]) 
    return np.array(x),np.array(y)

# Formating data into array for create sliding windows
array_training_set = np.array(training_set)
array_val_set = np.array(val_set)
array_test_set = np.array(test_set)

# Create sliding windows into training data
x_train, y_train = create_sliding_windows(array_training_set,len(array_training_set), lag)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
# Create sliding windows into validation data
x_val,y_val = create_sliding_windows(array_val_set,len(array_val_set),lag)
x_val = np.reshape(x_val, (x_val.shape[0],x_val.shape[1],1))
# Create sliding windows into test data
x_test,y_test = create_sliding_windows(array_test_set,len(array_test_set),lag)
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
learning_rate = 0.0001
hidden_unit = 64
batch_size = 32
epoch = 100

model = Sequential()

model.add(LSTM(units=hidden_unit, return_sequences=True, input_shape = (x_train.shape[1],1), activation="relu"))
model.add(Dropout(0.2))

model.add(LSTM(units=hidden_unit, return_sequences=True, activation="relu"))
model.add(Dropout(0.2))

model.add(LSTM(units=hidden_unit, return_sequences=False, activation="relu"))
model.add(Dropout(0.2))
Attention()

model.add(Dense(units=1))
model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate),loss='mean_squared_error')

pred = model.fit(x_train, y_train, validation_data=(x_val,y_val), batch_size=batch_size, epochs=epoch)
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 24/24 [==============================] - 4s 27ms/step - loss: 0.3206 - val_loss: 0.5107
# Epoch 2/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1387 - val_loss: 0.0335
# Epoch 3/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0298 - val_loss: 0.0462
# Epoch 4/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0179
# Epoch 5/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0153 - val_loss: 0.0079
# Epoch 6/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0021
# Epoch 7/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 9.3670e-04
# Epoch 8/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 9/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0013
# Epoch 10/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0067 - val_loss: 8.2392e-04
# Epoch 11/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 6.7258e-04
# Epoch 12/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 7.9132e-04
# Epoch 13/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0010
# Epoch 14/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 15/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 16/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 9.5769e-04
# Epoch 17/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0011
# Epoch 18/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 19/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0057 - val_loss: 8.1478e-04
# Epoch 20/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 7.7304e-04
# Epoch 21/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0011
# Epoch 22/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 23/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 24/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0012
# Epoch 25/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 9.9604e-04
# Epoch 26/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 27/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 28/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 8.8543e-04
# Epoch 29/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 30/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 9.9748e-04
# Epoch 31/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0010
# Epoch 32/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 8.9318e-04
# Epoch 33/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 8.7596e-04
# Epoch 34/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 35/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 8.8960e-04
# Epoch 36/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0010
# Epoch 37/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0013
# Epoch 38/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 9.3563e-04
# Epoch 39/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0045 - val_loss: 9.2420e-04
# Epoch 40/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 41/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 42/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 9.7151e-04
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 0.0012
# Epoch 44/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 45/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0010
# Epoch 46/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 47/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 48/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 9.8164e-04
# Epoch 49/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 9.6289e-04
# Epoch 50/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 9.2032e-04
# Epoch 51/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 9.8135e-04
# Epoch 52/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0012
# Epoch 53/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 54/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 55/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 9.5945e-04
# Epoch 56/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 9.3043e-04
# Epoch 57/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 58/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 9.8500e-04
# Epoch 59/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0015
# Epoch 60/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0010
# Epoch 61/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 9.0360e-04
# Epoch 62/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 9.6805e-04
# Epoch 63/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 64/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 65/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 9.3727e-04
# Epoch 66/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 9.4188e-04
# Epoch 67/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0010
# Epoch 68/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 69/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0026
# Epoch 70/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0010
# Epoch 71/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 72/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0012
# Epoch 73/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0011
# Epoch 74/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0014
# Epoch 75/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 76/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 77/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 78/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 79/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 0.0010
# Epoch 80/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 9.7118e-04
# Epoch 81/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0011
# Epoch 82/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 83/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 84/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 85/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 9.4736e-04
# Epoch 86/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 8.5032e-04
# Epoch 87/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 8.5410e-04
# Epoch 88/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 8.0339e-04
# Epoch 89/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0027 - val_loss: 9.8780e-04
# Epoch 90/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 8.5208e-04
# Epoch 91/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0031 - val_loss: 9.7520e-04
# Epoch 92/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0014
# Epoch 93/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 9.5705e-04
# Epoch 94/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 95/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0011
# Epoch 96/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 9.8479e-04
# Epoch 97/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 9.2763e-04
# Epoch 98/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0010
# Epoch 99/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 100/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0012

# %%
fig = plt.figure(figsize=(10, 4))
plt.plot(pred.history['loss'], label='train loss')
plt.plot(pred.history['val_loss'], label='val loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt.show()

# %%
learningrate_parameter = learning_rate
train_loss=pred.history['loss'][-1]
validation_loss=pred.history['val_loss'][-1]
learningrate_parameter=pd.DataFrame(data=[[learningrate_parameter, train_loss, validation_loss]],
                                    columns=['Learning Rate', 'Training Loss', 'Validation Loss'])
learningrate_parameter.set_index('Learning Rate')
# Out:
#                Training Loss  Validation Loss
# Learning Rate
# 0.0001              0.002654         0.001218

# %%
# Implementation model into data test
y_pred_test = model.predict(x_test)

# Invert normalization min-max
y_pred_invert_norm = scaler.inverse_transform(y_pred_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
set_test = dataset["Close"]

# %%
datacompare = pd.DataFrame()
datatest=np.array(set_test[totaldatatrain+totaldataval+lag:])
datapred= y_pred_invert_norm

datacompare['Data Test'] = datatest
datacompare['Prediction Results'] = datapred
datacompare
# Out:
#      Data Test  Prediction Results
# 0    17.219999           16.967020
# 1    17.059999           17.038517
# 2    16.860001           17.097397
# 3    16.620001           16.931215
# 4    15.740000           16.733225
# ..         ...                 ...
# 142  11.120000           11.265789
# 143  11.570000           11.254759
# 144  11.800000           11.256277
# 145  12.200000           11.537461
# 146  12.780000           11.736117
#
# [147 rows x 2 columns]

# %%
plt.figure(num=None, figsize=(10, 4), dpi=80,facecolor='w', edgecolor='k')
plt.title('Graph Comparison Data Actual and Data Prediction')
plt.plot(datacompare['Data Test'], color='red',label='Data Test')
plt.plot(datacompare['Prediction Results'], color='blue',label='Prediction Results')
plt.xlabel('Day')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape
MAPE(datatest, datapred)
# Out:
# 13.57694841174405

# %%
from sklearn.metrics import mean_squared_error
import math
MSE = mean_squared_error(datatest, datapred)
RMSE = math.sqrt(MSE)
print(RMSE)
# Out:
# 0.31412545196993896

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(
    y_true=datatest,
    y_pred=datapred
)
# Out:
# 0.24075970250260756
